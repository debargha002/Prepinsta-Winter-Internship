# %% [markdown]
# # Week 6 Assignment
# ## Cars Dataset Exploratory Data Analysis

# %%
# importing libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.impute import SimpleImputer

# %%
# laoding dataset
cars = pd.read_csv('E:/PrepInsta Winter Internship Program/Week 6/Indian Cars/cars_ds_final.csv')
cars.head()
# Out:
#    Unnamed: 0  Make      Model  Variant Ex-Showroom_Price Displacement  \
# 0           0  Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc
# 1           1  Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc
# 2           2  Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc
# 3           3  Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc
# 4           4  Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc
#
#    Cylinders  Valves_Per_Cylinder              Drivetrain  \
# 0        2.0                  2.0  RWD (Rear Wheel Drive)
# 1        2.0                  2.0  RWD (Rear Wheel Drive)
# 2        2.0                  2.0  RWD (Rear Wheel Drive)
# 3        2.0                  2.0  RWD (Rear Wheel Drive)
# 4        2.0                  2.0  RWD (Rear Wheel Drive)
#
#   Cylinder_Configuration  ... Leather_Wrapped_Steering Automatic_Headlamps  \
# 0                In-line  ...                      NaN                 NaN
# 1                In-line  ...                      NaN                 NaN
# 2                In-line  ...                      NaN                 NaN
# 3                In-line  ...                      NaN                 NaN
# 4                In-line  ...                      NaN                 NaN
#
#   Engine_Type ASR_/_Traction_Control Cruise_Control USB_Ports  \
# 0         NaN                    NaN            NaN       NaN
# 1         NaN                    NaN            NaN       NaN
# 2         NaN                    NaN            NaN       NaN
# 3         NaN                    NaN            NaN       NaN
# 4         NaN                    NaN            NaN       NaN
#
#   Heads-Up_Display Welcome_Lights Battery  Electric_Range
# 0              NaN            NaN     NaN             NaN
# 1              NaN            NaN     NaN             NaN
# 2              NaN            NaN     NaN             NaN
# 3              NaN            NaN     NaN             NaN
# 4              NaN            NaN     NaN             NaN
#
# [5 rows x 141 columns]

# %%
cars.shape
# Out:
# (1276, 141)

# %%
cars.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1276 entries, 0 to 1275
# Data columns (total 141 columns):
#  #    Column                                     Dtype
# ---   ------                                     -----
#  0    Unnamed: 0                                 int64
#  1    Make                                       object
#  2    Model                                      object
#  3    Variant                                    object
#  4    Ex-Showroom_Price                          object
#  5    Displacement                               object
#  6    Cylinders                                  float64
#  7    Valves_Per_Cylinder                        float64
#  8    Drivetrain                                 object
#  9    Cylinder_Configuration                     object
#  10   Emission_Norm                              object
#  11   Engine_Location                            object
#  12   Fuel_System                                object
#  13   Fuel_Tank_Capacity                         object
#  14   Fuel_Type                                  object
#  15   Height                                     object
#  16   Length                                     object
#  17   Width                                      object
#  18   Body_Type                                  object
#  19   Doors                                      float64
#  20   City_Mileage                               object
#  21   Highway_Mileage                            object
#  22   ARAI_Certified_Mileage                     object
#  23   ARAI_Certified_Mileage_for_CNG             object
#  24   Kerb_Weight                                object
#  25   Gears                                      object
#  26   Ground_Clearance                           object
#  27   Front_Brakes                               object
#  28   Rear_Brakes                                object
#  29   Front_Suspension                           object
#  30   Rear_Suspension                            object
#  31   Front_Track                                object
#  32   Rear_Track                                 object
#  33   Front_Tyre_&_Rim                           object
#  34   Rear_Tyre_&_Rim                            object
#  35   Power_Steering                             object
#  36   Power_Windows                              object
#  37   Power_Seats                                object
#  38   Keyless_Entry                              object
#  39   Power                                      object
#  40   Torque                                     object
#  41   Odometer                                   object
#  42   Speedometer                                object
#  43   Tachometer                                 object
#  44   Tripmeter                                  object
#  45   Seating_Capacity                           float64
#  46   Seats_Material                             object
#  47   Type                                       object
#  48   Wheelbase                                  object
#  49   Wheels_Size                                object
#  50   Start_/_Stop_Button                        object
#  51   12v_Power_Outlet                           object
#  52   Audiosystem                                object
#  53   Aux-in_Compatibility                       object
#  54   Average_Fuel_Consumption                   object
#  55   Basic_Warranty                             object
#  56   Bluetooth                                  object
#  57   Boot-lid_Opener                            object
#  58   Boot_Space                                 object
#  59   CD_/_MP3_/_DVD_Player                      object
#  60   Central_Locking                            object
#  61   Child_Safety_Locks                         object
#  62   Clock                                      object
#  63   Cup_Holders                                object
#  64   Distance_to_Empty                          object
#  65   Door_Pockets                               object
#  66   Engine_Malfunction_Light                   object
#  67   Extended_Warranty                          object
#  68   FM_Radio                                   object
#  69   Fuel-lid_Opener                            object
#  70   Fuel_Gauge                                 object
#  71   Handbrake                                  object
#  72   Instrument_Console                         object
#  73   Low_Fuel_Warning                           object
#  74   Minimum_Turning_Radius                     object
#  75   Multifunction_Display                      object
#  76   Sun_Visor                                  object
#  77   Third_Row_AC_Vents                         object
#  78   Ventilation_System                         object
#  79   Auto-Dimming_Rear-View_Mirror              object
#  80   Hill_Assist                                object
#  81   Gear_Indicator                             object
#  82   3_Point_Seat-Belt_in_Middle_Rear_Seat      object
#  83   Ambient_Lightning                          object
#  84   Cargo/Boot_Lights                          object
#  85   Drive_Modes                                object
#  86   Engine_Immobilizer                         object
#  87   High_Speed_Alert_System                    object
#  88   Lane_Watch_Camera/_Side_Mirror_Camera      object
#  89   Passenger_Side_Seat-Belt_Reminder          object
#  90   Seat_Back_Pockets                          object
#  91   Voice_Recognition                          object
#  92   Walk_Away_Auto_Car_Lock                    object
#  93   ABS_(Anti-lock_Braking_System)             object
#  94   Headlight_Reminder                         object
#  95   Adjustable_Headrests                       object
#  96   Gross_Vehicle_Weight                       object
#  97   Airbags                                    object
#  98   Door_Ajar_Warning                          object
#  99   EBD_(Electronic_Brake-force_Distribution)  object
#  100  Fasten_Seat_Belt_Warning                   object
#  101  Gear_Shift_Reminder                        object
#  102  Number_of_Airbags                          float64
#  103  Compression_Ratio                          object
#  104  Adjustable_Steering_Column                 object
#  105  Other_Specs                                object
#  106  Other_specs                                object
#  107  Parking_Assistance                         object
#  108  Key_Off_Reminder                           object
#  109  USB_Compatibility                          object
#  110  Android_Auto                               object
#  111  Apple_CarPlay                              object
#  112  Cigarette_Lighter                          object
#  113  Infotainment_Screen                        object
#  114  Multifunction_Steering_Wheel               object
#  115  Average_Speed                              object
#  116  EBA_(Electronic_Brake_Assist)              object
#  117  Seat_Height_Adjustment                     object
#  118  Navigation_System                          object
#  119  Second_Row_AC_Vents                        object
#  120  Tyre_Pressure_Monitoring_System            object
#  121  Rear_Center_Armrest                        object
#  122  iPod_Compatibility                         object
#  123  ESP_(Electronic_Stability_Program)         object
#  124  Cooled_Glove_Box                           object
#  125  Recommended_Tyre_Pressure                  object
#  126  Heated_Seats                               object
#  127  Turbocharger                               object
#  128  ISOFIX_(Child-Seat_Mount)                  object
#  129  Rain_Sensing_Wipers                        object
#  130  Paddle_Shifters                            object
#  131  Leather_Wrapped_Steering                   object
#  132  Automatic_Headlamps                        object
#  133  Engine_Type                                object
#  134  ASR_/_Traction_Control                     object
#  135  Cruise_Control                             object
#  136  USB_Ports                                  float64
#  137  Heads-Up_Display                           object
#  138  Welcome_Lights                             object
#  139  Battery                                    object
#  140  Electric_Range                             object
# dtypes: float64(6), int64(1), object(134)
# memory usage: 1.4+ MB

# %%
# dropping the "unnamed" column
cars.drop(columns=['Unnamed: 0'], axis=1, inplace=True)

# %%
# converting Ex-Showroom_Price ino numerical data
cars['Ex-Showroom_Price'] = cars['Ex-Showroom_Price'].str.replace('Rs.','').str.replace(',','')

# %%
cars['Ex-Showroom_Price'] = cars['Ex-Showroom_Price'].astype(int)

# %%
# creating a new column with the combination of columns "Make" and "Model"
cars['Name'] = cars['Make'] +'-'+ cars['Model']

# %%
cars.drop(columns=['Make','Model'], axis=1,inplace=True)

# %% [markdown]
# ## Data Cleaning
# Selecting useful columns that are relevant and useful out of the whole 140 columns.

# %%
df = cars[['Name','Variant','Ex-Showroom_Price','Displacement','Seating_Capacity','Cylinders','Drivetrain','Emission_Norm','Fuel_System',
           'Fuel_Tank_Capacity','Fuel_Type','Height','Length','Width','Body_Type','City_Mileage','ARAI_Certified_Mileage',
           'Gears','Ground_Clearance','Front_Brakes','Power_Steering','Power_Seats', 'Power','Torque','Speedometer','Odometer','Tripmeter',
           'Seating_Capacity','Type','Wheelbase','Average_Fuel_Consumption','Basic_Warranty',
           'Bluetooth','Number_of_Airbags','USB_Compatibility','Engine_Type','USB_Ports','Battery','Navigation_System']]

# %%
df.to_csv('new_car', index=False)

# %%
df = pd.read_csv('new_car')

# %%
## Removing cc from displacement column
df['Displacement']=df.Displacement.str.replace('cc','')

# %%
df.Fuel_Tank_Capacity.value_counts()
# Out:
# Fuel_Tank_Capacity
# 45 litres      125
# 35 litres      124
# 50 litres       94
# 60 litres       91
# 37 litres       79
#               ...
# 36 litres        1
# 90.5 litres      1
# 87 litres        1
# 72 litres        1
# 96 litres        1
# Name: count, Length: 63, dtype: int64

# %%
df['Fuel_Tank_Capacity']=df.Fuel_Tank_Capacity.str.replace('litres','')

# %%
df.Fuel_Tank_Capacity = df.Fuel_Tank_Capacity.astype(float)

# %%
# converting height, length and width into numerical column
df['Height'] = df.Height.str.replace('mm','')

# %%
df['Height'].astype(float)
# Out:
# 0       1652.0
# 1       1652.0
# 2       1652.0
# 3       1652.0
# 4       1652.0
#          ...
# 1271    1495.0
# 1272    1495.0
# 1273    1495.0
# 1274    1495.0
# 1275    1900.0
# Name: Height, Length: 1276, dtype: float64

# %%
df['Length'] = df.Length.str.replace('mm','')
df['Length'].astype(float)

df['Width'] = df.Width.str.replace('mm','')
df['Width'].astype(float)
# Out:
# 0       1750.0
# 1       1750.0
# 2       1750.0
# 3       1750.0
# 4       1750.0
#          ...
# 1271    1695.0
# 1272    1695.0
# 1273    1695.0
# 1274    1695.0
# 1275    1875.0
# Name: Width, Length: 1276, dtype: float64

# %%
# Power and Torque
df.Power.value_counts()
# Out:
# Power
# 83PS@6000rpm           52
# 75PS@4000rpm           37
# 90PS@4000rpm           29
# 100PS@3750RPM          28
# 68PS@6000rpm           25
#                        ..
# 248bhp@5200rpm          1
# 268PS@6350rpm           1
# 258bhp@5800-6100rpm     1
# 197hp@4500-6500rpm      1
# 202ps@3800rpm           1
# Name: count, Length: 372, dtype: int64

# %%
df.Torque.value_counts()
# Out:
# Torque
# 90Nm@3500rpm          42
# 200Nm@1750rpm         42
# 114Nm@4000rpm         27
# 350Nm@1750-2500rpm    26
# 104Nm@4000rpm         22
#                       ..
# 280Nm@1350-4600rpm     1
# 400 Nm @ 1750 RPM      1
# 400NM@1550rpm          1
# 420Nm@1500-3000rpm     1
# 441Nm@2000rpm          1
# Name: count, Length: 342, dtype: int64

# %%
## Removing unneccesary things using REGEX
df.Power = df['Power'].str.extract(r'(\d{1,4}).*').astype(int)

# %%
df.Torque = df['Torque'].str.extract(r'(\d{1,4}).*').astype(float)

# %%
df.Ground_Clearance = df['Ground_Clearance'].str.replace('mm','').astype(float)

# %% [markdown]
# For missing values, I will be using median for numerical column and mode for categorical column.

# %%
# Seperating cols into nnumerical and categorical
numerical_col = df.select_dtypes(include=['float64','int64','int32']).columns
categorical_col = df.select_dtypes(include=['object']).columns

# %%
num = SimpleImputer(strategy='median')
cat = SimpleImputer(strategy='most_frequent')

# %%
df[numerical_col] = num.fit_transform(df[numerical_col])
df[categorical_col] = cat.fit_transform(df[categorical_col])

# %%
df.isna().sum()
# Out:
# Name                        0
# Variant                     0
# Ex-Showroom_Price           0
# Displacement                0
# Seating_Capacity            0
# Cylinders                   0
# Drivetrain                  0
# Emission_Norm               0
# Fuel_System                 0
# Fuel_Tank_Capacity          0
# Fuel_Type                   0
# Height                      0
# Length                      0
# Width                       0
# Body_Type                   0
# City_Mileage                0
# ARAI_Certified_Mileage      0
# Gears                       0
# Ground_Clearance            0
# Front_Brakes                0
# Power_Steering              0
# Power_Seats                 0
# Power                       0
# Torque                      0
# Speedometer                 0
# Odometer                    0
# Tripmeter                   0
# Seating_Capacity.1          0
# Type                        0
# Wheelbase                   0
# Average_Fuel_Consumption    0
# Basic_Warranty              0
# Bluetooth                   0
# Number_of_Airbags           0
# USB_Compatibility           0
# Engine_Type                 0
# USB_Ports                   0
# Battery                     0
# Navigation_System           0
# dtype: int64

# %% [markdown]
# # Data Visualization
# ### Univariate Analysis

# %%
# barchart showing count of Ex Showroom Price
# Create a figure and axes
plt.figure(figsize=(10, 10))
ax = sns.histplot(data=df, x='Ex-Showroom_Price', log_scale=True, color='lightblue', bins=30)

# Adding labels and title
plt.title('Distribution of Ex-Showroom Price (Log Scale)', fontsize=16)
plt.xlabel('Ex-Showroom Price (log scale)', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Adding grid lines
ax.grid(axis='y', linestyle='--', alpha=0.7)

# Adding numbers above the bars
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='baseline', fontsize=8, color='black', xytext=(0, 5),
                textcoords='offset points')

# Show plot
plt.show()

# %%
# most used Fuel type
plt.figure(figsize=(6, 6))
ax = sns.countplot(data=df, x='Fuel_Type', palette='viridis')  # Adjust the color palette as needed

# Adding labels
plt.title('Most Used Fuel Type')
plt.xlabel('Fuel Type')
plt.ylabel('Count')

# Adding numbers above the bars
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='baseline', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.show()
# Out:
# C:\Users\debar\AppData\Local\Temp\ipykernel_8284\794346096.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, x='Fuel_Type', palette='viridis')  # Adjust the color palette as needed

# %%
maker = df.Name.value_counts().head(10)
maker
# Out:
# Name
# Tata-Nexon              99
# Mahindra-Kuv100 Nxt     22
# Jeep-Compass            21
# Mahindra-Xuv500         21
# Honda-Amaze             20
# Hyundai-Creta           18
# Kia-Seltos              16
# Toyota-Innova Crysta    16
# Maruti Suzuki-Swift     14
# Maruti Suzuki-Ciaz      14
# Name: count, dtype: int64

# %%
# pie chart showing top 10 cars by percentage
plt.figure(figsize=(10,10))
plt.pie(x=maker,labels=['Tata-Nexon','Mahindra-Kuv100 Nxt','Jeep-Compass','Mahindra-Xuv500',
'Honda-Amaze','Hyundai-Creta','Kia-Seltos','Toyota-Innova Crysta','Maruti Suzuki-Swift','Maruti Suzuki-Ciaz'],autopct='%1.1f%%')
plt.title('Top 10 Cars')
plt.tight_layout()

# %%
# bar chart showing most used number of airbags
plt.figure(figsize=(10, 8))
ax = sns.countplot(x=df['Number_of_Airbags'], palette='viridis')  # Adjust the color palette as needed

# Adding labels and title
plt.title('Most Number of Airbags Used')
plt.xlabel('Number of Airbags')
plt.ylabel('Count')

# Adding numbers above the bars
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='baseline', fontsize=15, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\debar\AppData\Local\Temp\ipykernel_8284\1944459109.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x=df['Number_of_Airbags'], palette='viridis')  # Adjust the color palette as needed

# %%
power = df.Power.value_counts().head(10)
power_label = df.Power.value_counts().head(10).index
torque = df.Torque.value_counts().head(10)
torque_label = df.Torque.value_counts().head(10).index

# %%
# Create a figure with subplots
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(14, 12))

# Plot the first pie chart (Power)
axes[0].pie(x=power, labels=power_label, autopct='%1.1f%%', startangle=90, colors=plt.cm.Paired.colors)
axes[0].set_title('Most Power Used by a Vehicle in NM', fontsize=14)

# Plot the second pie chart (Torque)
axes[1].pie(x=torque, labels=torque_label, autopct='%1.1f%%', startangle=90, colors=plt.cm.Paired.colors)
axes[1].set_title('Most Torque Used by a Vehicle in NM', fontsize=14)

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %% [markdown]
# ### Bivariate Analysis

# %%
corr = df.corr(numeric_only = True)

# %%
corr
# Out:
#                     Ex-Showroom_Price  Seating_Capacity  Cylinders  \
# Ex-Showroom_Price            1.000000         -0.307150   0.817001
# Seating_Capacity            -0.307150          1.000000  -0.313152
# Cylinders                    0.817001         -0.313152   1.000000
# Fuel_Tank_Capacity           0.454805          0.029613   0.637512
# Ground_Clearance            -0.032621          0.257605  -0.021425
# Power                        0.855172         -0.326305   0.880504
# Torque                       0.702153         -0.141714   0.764419
# Seating_Capacity.1          -0.307150          1.000000  -0.313152
# Number_of_Airbags            0.335710         -0.043493   0.448188
# USB_Ports                   -0.209113          0.072918  -0.089052
#
#                     Fuel_Tank_Capacity  Ground_Clearance     Power    Torque  \
# Ex-Showroom_Price             0.454805         -0.032621  0.855172  0.702153
# Seating_Capacity              0.029613          0.257605 -0.326305 -0.141714
# Cylinders                     0.637512         -0.021425  0.880504  0.764419
# Fuel_Tank_Capacity            1.000000          0.122058  0.662256  0.726607
# Ground_Clearance              0.122058          1.000000 -0.020029  0.077282
# Power                         0.662256         -0.020029  1.000000  0.854995
# Torque                        0.726607          0.077282  0.854995  1.000000
# Seating_Capacity.1            0.029613          0.257605 -0.326305 -0.141714
# Number_of_Airbags             0.634343          0.081411  0.534421  0.600943
# USB_Ports                     0.041416          0.010248 -0.140767 -0.062385
#
#                     Seating_Capacity.1  Number_of_Airbags  USB_Ports
# Ex-Showroom_Price            -0.307150           0.335710  -0.209113
# Seating_Capacity              1.000000          -0.043493   0.072918
# Cylinders                    -0.313152           0.448188  -0.089052
# Fuel_Tank_Capacity            0.029613           0.634343   0.041416
# Ground_Clearance              0.257605           0.081411   0.010248
# Power                        -0.326305           0.534421  -0.140767
# Torque                       -0.141714           0.600943  -0.062385
# Seating_Capacity.1            1.000000          -0.043493   0.072918
# Number_of_Airbags            -0.043493           1.000000   0.042070
# USB_Ports                     0.072918           0.042070   1.000000

# %%
# correlation heatmap showing positive and negative relationship among numeric variables
plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
sns.pairplot(data=df[['Ex-Showroom_Price','Power','Torque','Number_of_Airbags','Ground_Clearance']])

# %%
plt.figure(figsize=(12, 8))

# Specify dodge=True to ensure bars are not stacked
sns.barplot(data=df.head(250), x='Body_Type', y='Ex-Showroom_Price', hue='Fuel_Type', palette='Set1', dodge=True)

# Adding labels and title
plt.title('Bar Plot of Body Type vs. Ex-Showroom Price', fontsize=16)
plt.xlabel('Body Type', fontsize=14)
plt.ylabel('Ex-Showroom Price', fontsize=14)

# Adding legend
plt.legend(title='Fuel Type', title_fontsize='12', fontsize='10', loc='upper right')

# Adding grid
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(x='Cylinders', y='Ex-Showroom_Price', data=df, palette='husl')

# Adding labels and title
plt.title('Price vs Cylinders', fontsize=16)
plt.xlabel('Cylinders', fontsize=14)
plt.ylabel('Ex-Showroom Price', fontsize=14)

# Adding grid
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adding horizontal lines for quartiles
for i in range(1, len(df['Cylinders'].unique()) + 1):
    plt.axvline(x=i - 0.5, color='gray', linestyle='--', linewidth=0.8)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\debar\AppData\Local\Temp\ipykernel_8284\1506642653.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Cylinders', y='Ex-Showroom_Price', data=df, palette='husl')
