# %% [markdown]
# # Murder Mystery using SQL

# %%
# importing libraries

import pandas as pd
import sqlite3 as sql
import  numpy as np
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Loading Database & Tables

# %%
database = r"sql-murder-mystery.db"
connection = sql.connect(database)

# %%
query_1 = 'SELECT * FROM crime_scene_report'
crime_scene_report =  pd.read_sql_query(query_1, connection)
crime_scene_report.head()
# Out:
#        date     type                                        description  \
# 0  20180115  robbery  A Man Dressed as Spider-Man Is on a Robbery Spree
# 1  20180115   murder                  Life? Dont talk to me about life.
# 2  20180115   murder  Mama, I killed a man, put a gun against his he...
# 3  20180215   murder                         REDACTED REDACTED REDACTED
# 4  20180215   murder  Someone killed the guard! He took an arrow to ...
#
#        city
# 0       NYC
# 1    Albany
# 2      Reno
# 3  SQL City
# 4  SQL City

# %%
query_2 =  'SELECT * FROM drivers_license'
drivers_license =  pd.read_sql_query(query_2, connection)
drivers_license.head()
# Out:
#        id  age  height eye_color hair_color  gender plate_number  car_make  \
# 0  100280   72      57     brown        red    male       P24L4U     Acura
# 1  100460   63      72     brown      brown  female       XF02T6  Cadillac
# 2  101029   62      74     green      green  female       VKY5KR     Scion
# 3  101198   43      54     amber      brown  female       Y5NZ08    Nissan
# 4  101255   18      79      blue       grey  female       5162Z1     Lexus
#
#   car_model
# 0       MDX
# 1       SRX
# 2        xB
# 3     Rogue
# 4        GS

# %%
query_3 = 'SELECT * FROM facebook_event_checkin'
facebook_event_checkin = pd.read_sql_query(query_3, connection)
facebook_event_checkin.head()
# Out:
#    person_id  event_id                                         event_name  \
# 0      28508      5880    Nudists are people who wear one-button suits.\n
# 1      63713      3865  but that's because it's the best book on anyth...
# 2      63713      3999           If Murphy's Law can go wrong, it will.\n
# 3      63713      6436  Old programmers never die.  They just branch t...
# 4      82998      4470               Help a swallow land at Capistrano.\n
#
#        date
# 0  20170913
# 1  20171009
# 2  20170502
# 3  20170926
# 4  20171022

# %%
query_4 = 'SELECT * FROM get_fit_now_check_in'
get_fit_now_check_in = pd.read_sql_query(query_4, connection)
get_fit_now_check_in.head()
# Out:
#   membership_id  check_in_date  check_in_time  check_out_time
# 0         NL318       20180212            329             365
# 1         NL318       20170811            469             920
# 2         NL318       20180429            506             554
# 3         NL318       20180128            124             759
# 4         NL318       20171027            418            1019

# %%
query_5 = 'SELECT * FROM get_fit_now_member'
get_fit_now_member = pd.read_sql_query(query_5, connection)
get_fit_now_member.head()
# Out:
#       id  person_id                name  membership_start_date  \
# 0  NL318      65076     Everette Koepke               20170926
# 1  AOE21      39426        Noe Locascio               20171005
# 2  2PN28      63823  Jeromy Heitschmidt               20180215
# 3  0YJ24      80651      Waneta Wellard               20171206
# 4  3A08L      32858        Mei Bianchin               20170401
#
#   membership_status
# 0              gold
# 1           regular
# 2            silver
# 3              gold
# 4            silver

# %%
query_6 = 'SELECT * FROM income '
income = pd.read_sql_query(query_6, connection)
income.head()
# Out:
#          ssn  annual_income
# 0  100009868          52200
# 1  100169584          64500
# 2  100300433          74400
# 3  100355733          35900
# 4  100366269          73000

# %%
query_7 = 'SELECT * FROM interview'
interview = pd.read_sql_query(query_7, connection)
interview.head()
# Out:
#    person_id                                         transcript
# 0      28508                ‘I deny it!’ said the March Hare.\n
# 1      63713                                                 \n
# 2      86208      way, and the whole party swam to the shore.\n
# 3      35267  lessons in here? Why, there’s hardly room for ...
# 4      33856                                                 \n

# %%
query_8 = 'SELECT * FROM person'
person = pd.read_sql_query(query_8, connection)
person.head()
# Out:
#       id                 name  license_id  address_number address_street_name  \
# 0  10000   Christoper Peteuil      993845             624        Bankhall Ave
# 1  10007  Kourtney Calderwood      861794            2791       Gustavus Blvd
# 2  10010            Muoi Cary      385336             741     Northwestern Dr
# 3  10016          Era Moselle      431897            1987       Wood Glade St
# 4  10025         Trena Hornby      550890             276       Daws Hill Way
#
#          ssn
# 0  747714076
# 1  477972044
# 2  828638512
# 3  614621061
# 4  223877684

# %% [markdown]
# ### 1) Retrieve Crime Scene Report
# Task: Run a query to retrieve the crime scene report for the murder that occurred on Jan.15, 2018, in SQL City. Gather all available details from the report.

# %%
task_1 = "SELECT * FROM crime_scene_report WHERE date = 20180115 AND type= 'murder' AND city = 'SQL City'"
murder_on_jan15 = pd.read_sql_query(task_1,connection)
pd.set_option('display.max_colwidth', None)
murder_on_jan15
# Out:
#        date    type  \
# 0  20180115  murder
#
#                                                                                                                                                                                  description  \
# 0  Security footage shows that there were 2 witnesses. The first witness lives at the last house on "Northwestern Dr". The second witness, named Annabel, lives somewhere on "Franklin Ave".
#
#        city
# 0  SQL City

# %% [markdown]
# ### 2) Witness Personal Details
# Task: Check the personal details of witnesses involved in the case. Retrieve their names, addresses, and any other relevant information.

# %%
task_2 = "SELECT * FROM person where address_street_name=='Northwestern Dr'"
location = pd.read_sql_query(task_2, connection)
print("Address Number: ", max(location["address_number"]))
# Out:
# Address Number:  4919

# %%
task_2_a = "SELECT * FROM person where address_number=='4919'"
first_witness = pd.read_sql_query(task_2_a, connection)
first_witness
# Out:
#       id            name  license_id  address_number address_street_name  \
# 0  14887  Morty Schapiro      118009            4919     Northwestern Dr
#
#          ssn
# 0  111564949

# %%
task_2_b = "SELECT * FROM person where address_street_name = 'Franklin Ave' AND name LIKE 'Annabel%'"
second_witness = pd.read_sql_query(task_2_b, connection)
second_witness
# Out:
#       id            name  license_id  address_number address_street_name  \
# 0  16371  Annabel Miller      490173             103        Franklin Ave
#
#          ssn
# 0  318771143

# %% [markdown]
# ### 3) View Witness Interviews:
# Task: Access the recorded interviews of witnesses conducted after the murder. Gather insights into their statements and potential clues.

# %%
interview.head()
# Out:
#    person_id  \
# 0      28508
# 1      63713
# 2      86208
# 3      35267
# 4      33856
#
#                                                                 transcript
# 0                                      ‘I deny it!’ said the March Hare.\n
# 1                                                                       \n
# 2                            way, and the whole party swam to the shore.\n
# 3  lessons in here? Why, there’s hardly room for YOU, and no room at all\n
# 4                                                                       \n

# %%
task_3 = "SELECT * FROM interview WHERE person_id =16371"
interview_of_witnesses_1 = pd.read_sql_query(task_3, connection)
interview_of_witnesses_1
# Out:
#    person_id  \
# 0      16371
#
#                                                                                                               transcript
# 0  I saw the murder happen, and I recognized the killer from my gym when I was working out last week on January the 9th.

# %%
task_3_a = "SELECT * FROM interview WHERE person_id =14887"
interview_of_witnesses_2 = pd.read_sql_query(task_3_a, connection)
interview_of_witnesses_2
# Out:
#    person_id  \
# 0      14887
#
#                                                                                                                                                                                                                         transcript
# 0  I heard a gunshot and then saw a man run out. He had a "Get Fit Now Gym" bag. The membership number on the bag started with "48Z". Only gold members have those bags. The man got into a car with a plate that included "H42W".

# %% [markdown]
# The witness had said that the murderer is a **Male** with a gold gym membership.

# %% [markdown]
# ### 4) Check Gym Database
# Task: Investigate the gym database using details obtained from the crime scene report and witness interviews. Look for any gym-related information that might be relevant.

# %%
 get_fit_now_member.head()
# Out:
#       id  person_id                name  membership_start_date  \
# 0  NL318      65076     Everette Koepke               20170926
# 1  AOE21      39426        Noe Locascio               20171005
# 2  2PN28      63823  Jeromy Heitschmidt               20180215
# 3  0YJ24      80651      Waneta Wellard               20171206
# 4  3A08L      32858        Mei Bianchin               20170401
#
#   membership_status
# 0              gold
# 1           regular
# 2            silver
# 3              gold
# 4            silver

# %% [markdown]
# As said before by the witness, the suspect had membership number "48Z" in his bag and he had a gold membership.

# %%
task_4 = "SELECT * FROM get_fit_now_member WHERE membership_status= 'gold' AND id LIKE '48Z%'"
suspects = pd.read_sql_query(task_4, connection)
suspects
# Out:
#       id  person_id           name  membership_start_date membership_status
# 0  48Z7A      28819   Joe Germuska               20160305              gold
# 1  48Z55      67318  Jeremy Bowers               20160101              gold

# %% [markdown]
# Both these suspects share the same gym-ID "48Z" and have gold membership. Now, lets find the car details.

# %% [markdown]
# ### 5) Check Car Details
# Task: Examine the car details associated with the crime scene. Retrieve information about the vehicles present during the incident.

# %%
task_5 = "SELECT * FROM drivers_license WHERE plate_number LIKE '%H42W%' AND gender = 'male'"
car_details =pd.read_sql_query(task_5, connection)
car_details
# Out:
#        id  age  height eye_color hair_color gender plate_number   car_make  \
# 0  423327   30      70     brown      brown   male       0H42W2  Chevrolet
# 1  664760   21      71     black      black   male       4H42WR     Nissan
#
#   car_model
# 0  Spark LS
# 1    Altima

# %% [markdown]
# ### 6) Personal Details
# Task: Identify and collect personal details mentioned in the previous query. This includes names, addresses, and any additional details.

# %%
# we have 2 males who're having car plate similar to "H42W"
task_6 = "SELECT * FROM  drivers_license WHERE id= 423327"
suspect_car_details = pd.read_sql_query(task_6,connection)
suspect_car_details
# Out:
#        id  age  height eye_color hair_color gender plate_number   car_make  \
# 0  423327   30      70     brown      brown   male       0H42W2  Chevrolet
#
#   car_model
# 0  Spark LS

# %%
task_6_a = "SELECT * FROM person WHERE license_id=423327"
suspect_personal_detail = pd.read_sql_query(task_6_a,connection)
suspect_personal_detail
# Out:
#       id           name  license_id  address_number    address_street_name  \
# 0  67318  Jeremy Bowers      423327             530  Washington Pl, Apt 3A
#
#          ssn
# 0  871539279

# %% [markdown]
# Thus, the male driver "Jeremy Bowers" is the suspect who drives a Chevrolet Spark LS with licese plate number H42Z.

# %% [markdown]
# ### 7) Membership Status at the Gym
# Task: Determine who is identified in the previous query as a member of the gym. Utilize the gym database to confirm their membership status.

# %%
# checking if Jeremy Bowers was present on 15th January
task_7 = "SELECT * FROM get_fit_now_member WHERE name = 'Jeremy Bowers'"
jeremy_bowers_gym = pd.read_sql_query(task_7,connection)
jeremy_bowers_gym
# Out:
#       id  person_id           name  membership_start_date membership_status
# 0  48Z55      67318  Jeremy Bowers               20160101              gold

# %%
task_7_a = "SELECT * from interview WHERE person_id= 67318"
interview_of_the_murderer = pd.read_sql_query(task_7_a,connection)
interview_of_the_murderer
# Out:
#    person_id  \
# 0      67318
#
#                                                                                                                                                                                                                                            transcript
# 0  I was hired by a woman with a lot of money. I don't know her name but I know she's around 5'5" (65") or 5'7" (67"). She has red hair and she drives a Tesla Model S. I know that she attended the SQL Symphony Concert 3 times in December 2017.\n

# %% [markdown]
# This indicates that there's a woman mastermind present behind the murder who is the primary person behind all this. Bowers was contracted for the murder.
# According to Bowers, the woman is "wealthy, drives a Tesla Model S, has red hair, and went to three SQL Symphony concerts in December of 2017."

# %%
task_7_b = " SELECT * FROM drivers_license WHERE hair_color ='red' AND car_make= 'Tesla'  AND gender ='female'"
culprit_details = pd.read_sql_query(task_7_b, connection)
culprit_details
# Out:
#        id  age  height eye_color hair_color  gender plate_number car_make  \
# 0  202298   68      66     green        red  female       500123    Tesla
# 1  291182   65      66      blue        red  female       08CM64    Tesla
# 2  918773   48      65     black        red  female       917UU3    Tesla
#
#   car_model
# 0   Model S
# 1   Model S
# 2   Model S

# %% [markdown]
# Records indicate that 3 women with similar suspicion patterns. Let's examine which of these three went to the SQL Symphony Concert three times in December 2017.

# %%
task_7_c = "SELECT *FROM person WHERE license_id = '202298' OR license_id = '291182' OR license_id = '918773'"
culprit = pd.read_sql_query(task_7_c,connection)
culprit
# Out:
#       id              name  license_id  address_number address_street_name  \
# 0  78881          Red Korb      918773             107         Camerata Dr
# 1  90700     Regina George      291182             332           Maple Ave
# 2  99716  Miranda Priestly      202298            1883          Golden Ave
#
#          ssn
# 0  961388910
# 1  337169072
# 2  987756388

# %%
task_7_d = "SELECT person_id, count(*), event_name FROM facebook_event_checkin  GROUP BY person_id having count(*) = 3 AND event_name = 'SQL Symphony Concert' AND date like '%201712%'"
culprit_a = pd.read_sql_query(task_7_d, connection)
culprit_a
# Out:
#    person_id  count(*)            event_name
# 0      24556         3  SQL Symphony Concert
# 1      99716         3  SQL Symphony Concert

# %% [markdown]
# Therefore, we found that the mastermind behind this murder is `Miranda Priesly` who paid **Jeremy Bowers** for the murder.
#
# The case is solved.
